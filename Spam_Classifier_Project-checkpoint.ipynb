# %%
import pandas as pd
import numpy as np
import en_core_web_sm

# %%
nlp = en_core_web_sm.load()

# %%
data = pd.read_csv('https://techlearn-cdn.s3.amazonaws.com/project_GmailSpamClassification/spam.csv',encoding='cp1252')

# %%
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data = data[['v1','v2']]

# %%
data['v1'] = data['v1'].apply(lambda x:0 if x=='ham' else 1)

# %%
data
# Out:
#       v1                                                 v2
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
# ...   ..                                                ...
# 5567   1  This is the 2nd time we have tried 2 contact u...
# 5568   0              Will Ì_ b going to esplanade fr home?
# 5569   0  Pity, * was in mood for that. So...any other s...
# 5570   0  The guy did some bitching but I acted like i'd...
# 5571   0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
### Text Pre-Processing
def process(x):
    temp = []
    document = nlp(x.lower())
    print(document)
    for i in document:
        if i.is_stop!=True and i.is_punct!= True:
            print(i)
            temp.append(i.lemma_)
            print(temp)
        else:
            pass
        
    return (' '.join(temp))
##

# %%
data['v2'] = data['v2'].apply(lambda x: process(x))
# Out:
# go until jurong point, crazy.. available only in bugis n great world la e buffet... cine there got amore wat...
# jurong
# ['jurong']
# point
# ['jurong', 'point']
# crazy
# ['jurong', 'point', 'crazy']
# available
# ['jurong', 'point', 'crazy', 'available']
# bugis
# ['jurong', 'point', 'crazy', 'available', 'bugis']
# n
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n']
# great
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great']
# world
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world']
# la
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la']
# e
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e']
# buffet
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet']
# cine
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine']
# got
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'get']
# amore
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'get', 'amore']
# wat
# ['jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'get', 'amore', 'wat']
# ok lar... joking wif u oni...
# ok
# ['ok']
# lar
# ['ok', 'lar']
# joking
# ['ok', 'lar', 'joking']
# wif
# ['ok', 'lar', 'joking', 'wif']
# u
# ['ok', 'lar', 'joking', 'wif', 'u']
# oni
# ['ok', 'lar', 'joking', 'wif', 'u', 'oni']
# free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005. text fa to 87121 to receive entry question(std txt rate)t&c's apply 08452810075over18's
# free
# ['free']
# entry
# ['free', 'entry']
# 2
# ['free', 'entry', '2']
# wkly
# ['free', 'entry', '2', 'wkly']
# comp
# ['free', 'entry', '2', 'wkly', 'comp']
# win
# ['free', 'entry', '2', 'wkly', 'comp', 'win']
# fa
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa']
# cup
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup']
# final
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final']
# tkts
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts']
# 21st
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st']
# 2005
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005']
# text
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text']
# fa
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa']
# 87121
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121']
# receive
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive']
# entry
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive', 'entry']
# question(std
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive', 'entry', 'question(std']
# txt
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive', 'entry', 'question(std', 'txt']
# rate)t&c
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive', 'entry', 'question(std', 'txt', 'rate)t&c']
# apply
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive', 'entry', 'question(std', 'txt', 'rate)t&c', 'apply']
# 08452810075over18
# ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', '2005', 'text', 'fa', '87121', 'receive', 'entry', 'question(std', 'txt', 'rate)t&c', 'apply', '08452810075over18']
# u dun say so early hor... u c already then say...
# u
# ['u']
# dun
# ['u', 'dun']
# early
# ['u', 'dun', 'early']
# hor
# ['u', 'dun', 'early', 'hor']
# u
# ['u', 'dun', 'early', 'hor', 'u']
# c
# ['u', 'dun', 'early', 'hor', 'u', 'c']
# nah i don't think he goes to usf, he lives around here though
# nah
# ['nah']
# think
# ['nah', 'think']
# goes
# ['nah', 'think', 'go']
# usf
# ['nah', 'think', 'go', 'usf']
# lives
# ['nah', 'think', 'go', 'usf', 'live']
# freemsg hey there darling it's been 3 week's now and no word back! i'd like some fun you up for it still? tb ok! xxx std chgs to send, å£1.50 to rcv
# freemsg
# ['freemsg']
# hey
# ['freemsg', 'hey']
# darling
# ['freemsg', 'hey', 'darle']
# 3
# ['freemsg', 'hey', 'darle', '3']
# week
# ['freemsg', 'hey', 'darle', '3', 'week']
# word
# ['freemsg', 'hey', 'darle', '3', 'week', 'word']
# like
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like']
# fun
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun']
# tb
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb']
# ok
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok']
# xxx
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok', 'xxx']
# std
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok', 'xxx', 'std']
# chgs
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok', 'xxx', 'std', 'chgs']
# send
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok', 'xxx', 'std', 'chgs', 'send']
# å£1.50
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok', 'xxx', 'std', 'chgs', 'send', 'å£1.50']
# rcv
# ['freemsg', 'hey', 'darle', '3', 'week', 'word', 'like', 'fun', 'tb', 'ok', 'xxx', 'std', 'chgs', 'send', 'å£1.50', 'rcv']
# even my brother is not like to speak with me. they treat me like aids patent.
# brother
# ['brother']
# like
# ['brother', 'like']
# speak
# ['brother', 'like', 'speak']
# treat
# ['brother', 'like', 'speak', 'treat']
# like
# ['brother', 'like', 'speak', 'treat', 'like']
# aids
# ['brother', 'like', 'speak', 'treat', 'like', 'aids']
# patent
# ['brother', 'like', 'speak', 'treat', 'like', 'aids', 'patent']
# as per your request 'melle melle (oru minnaminunginte nurungu vettam)' has been set as your callertune for all callers. press *9 to copy your friends callertune
# request
# ['request']
# melle
# ['request', 'melle']
# melle
# ['request', 'melle', 'melle']
# oru
# ['request', 'melle', 'melle', 'oru']
# minnaminunginte
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte']
# nurungu
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu']
# vettam
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam']
# set
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set']
# callertune
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune']
# callers
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'caller']
# press
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'caller', 'press']
# 9
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'caller', 'press', '9']
# copy
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'caller', 'press', '9', 'copy']
# friends
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'caller', 'press', '9', 'copy', 'friend']
# callertune
# ['request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'caller', 'press', '9', 'copy', 'friend', 'callertune']
# winner!! as a valued network customer you have been selected to receivea å£900 prize reward! to claim call 09061701461. claim code kl341. valid 12 hours only.
# winner
# ['winner']
# valued
# ['winner', 'value']
# network
# ['winner', 'value', 'network']
# customer
# ['winner', 'value', 'network', 'customer']
# selected
# ['winner', 'value', 'network', 'customer', 'select']
# receivea
# ['winner', 'value', 'network', 'customer', 'select', 'receivea']
# å£900
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900']
# prize
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize']
# reward
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward']
# claim
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim']
# 09061701461
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461']
# claim
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461', 'claim']
# code
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461', 'claim', 'code']
# kl341
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461', 'claim', 'code', 'kl341']
# valid
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461', 'claim', 'code', 'kl341', 'valid']
# 12
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461', 'claim', 'code', 'kl341', 'valid', '12']
# hours
# ['winner', 'value', 'network', 'customer', 'select', 'receivea', 'å£900', 'prize', 'reward', 'claim', '09061701461', 'claim', 'code', 'kl341', 'valid', '12', 'hour']
# had your mobile 11 months or more? u r entitled to update to the latest colour mobiles with camera for free! call the mobile update co free on 08002986030
# mobile
# ['mobile']
# 11
# ['mobile', '11']
# months
# ['mobile', '11', 'month']
# u
# ['mobile', '11', 'month', 'u']
# r
# ['mobile', '11', 'month', 'u', 'r']
# entitled
# ['mobile', '11', 'month', 'u', 'r', 'entitle']
# update
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update']
# latest
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late']
# colour
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour']
# mobiles
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile']
# camera
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera']
# free
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera', 'free']
# mobile
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera', 'free', 'mobile']
# update
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera', 'free', 'mobile', 'update']
# co
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera', 'free', 'mobile', 'update', 'co']
# free
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera', 'free', 'mobile', 'update', 'co', 'free']
# 08002986030
# ['mobile', '11', 'month', 'u', 'r', 'entitle', 'update', 'late', 'colour', 'mobile', 'camera', 'free', 'mobile', 'update', 'co', 'free', '08002986030']
# i'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? i've cried enough today.
# gon
# ['go']
# na
# ['go', 'to']
# home
# ['go', 'to', 'home']
# soon
# ['go', 'to', 'home', 'soon']
# want
# ['go', 'to', 'home', 'soon', 'want']
# talk
# ['go', 'to', 'home', 'soon', 'want', 'talk']
# stuff
# ['go', 'to', 'home', 'soon', 'want', 'talk', 'stuff']
# anymore
# ['go', 'to', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore']
# tonight
# ['go', 'to', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight']
# k
# ['go', 'to', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', 'k']
# cried
# ['go', 'to', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', 'k', 'cry']
# today
# ['go', 'to', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', 'k', 'cry', 'today']
# six chances to win cash! from 100 to 20,000 pounds txt> csh11 and send to 87575. cost 150p/day, 6days, 16+ tsandcs apply reply hl 4 info
# chances
# ['chance']
# win
# ['chance', 'win']
# cash
# ['chance', 'win', 'cash']
# 100
# ['chance', 'win', 'cash', '100']
# 20,000
# ['chance', 'win', 'cash', '100', '20,000']
# pounds
# ['chance', 'win', 'cash', '100', '20,000', 'pound']
# txt
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt']
# >
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>']
# csh11
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11']
# send
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send']
# 87575
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575']
# cost
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost']
# 150p
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p']
# day
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day']
# 6days
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days']
# 16
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16']
# +
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+']
# tsandcs
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+', 'tsandc']
# apply
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+', 'tsandc', 'apply']
# reply
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+', 'tsandc', 'apply', 'reply']
# hl
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+', 'tsandc', 'apply', 'reply', 'hl']
# 4
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+', 'tsandc', 'apply', 'reply', 'hl', '4']
# info
# ['chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', '>', 'csh11', 'send', '87575', 'cost', '150p', 'day', '6days', '16', '+', 'tsandc', 'apply', 'reply', 'hl', '4', 'info']
# urgent! you have won a 1 week free membership in our å£100,000 prize jackpot! txt the word: claim to no: 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18
# urgent
# ['urgent']
# won
# ['urgent', 'win']
# 1
# ['urgent', 'win', '1']
# week
# ['urgent', 'win', '1', 'week']
# free
# ['urgent', 'win', '1', 'week', 'free']
# membership
# ['urgent', 'win', '1', 'week', 'free', 'membership']
# å£100,000
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000']
# prize
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize']
# jackpot
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot']
# txt
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt']
# word
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word']
# claim
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim']
# 81010
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010']
# t&c
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c']
# www.dbuk.net
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net']
# lccltd
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net', 'lccltd']
# pobox
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net', 'lccltd', 'pobox']
# 4403ldnw1a7rw18
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18']
# i've been searching for the right words to thank you for this breather. i promise i wont take your help for granted and will fulfil my promise. you have been wonderful and a blessing at all times.
# searching
# ['search']
# right
# ['search', 'right']
# words
# ['search', 'right', 'word']
# thank
# ['search', 'right', 'word', 'thank']
# breather
# ['search', 'right', 'word', 'thank', 'breather']
# promise
# ['search', 'right', 'word', 'thank', 'breather', 'promise']
# wo
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will']
# nt
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not']
# help
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help']
# granted
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help', 'grant']
# fulfil
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help', 'grant', 'fulfil']
# promise
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help', 'grant', 'fulfil', 'promise']
# wonderful
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help', 'grant', 'fulfil', 'promise', 'wonderful']
# blessing
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help', 'grant', 'fulfil', 'promise', 'wonderful', 'blessing']
# times
# ['search', 'right', 'word', 'thank', 'breather', 'promise', 'will', 'not', 'help', 'grant', 'fulfil', 'promise', 'wonderful', 'blessing', 'time']
# i have a date on sunday with will!!
# date
# ['date']
# sunday
# ['date', 'sunday']
# xxxmobilemovieclub: to use your credit, click the wap link in the next txt message or click here>> http://wap. xxxmobilemovieclub.com?n=qjkgighjjgcbl
# xxxmobilemovieclub
# ['xxxmobilemovieclub']
# use
# ['xxxmobilemovieclub', 'use']
# credit
# ['xxxmobilemovieclub', 'use', 'credit']
# click
# ['xxxmobilemovieclub', 'use', 'credit', 'click']
# wap
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap']
# link
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link']
# txt
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt']
# message
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt', 'message']
# click
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt', 'message', 'click']
# >
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt', 'message', 'click', '>']
# >
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt', 'message', 'click', '>', '>']
# http://wap
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt', 'message', 'click', '>', '>', 'http://wap']
# xxxmobilemovieclub.com?n=qjkgighjjgcbl
# ['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'txt', 'message', 'click', '>', '>', 'http://wap', 'xxxmobilemovieclub.com?n=qjkgighjjgcbl']
# oh k...i'm watching here:)
# oh
# ['oh']
# k
# ['oh', 'k']
# i'm
# ['oh', 'k', "i'm"]
# watching
# ['oh', 'k', "i'm", 'watch']
# eh u remember how 2 spell his name... yes i did. he v naughty make until i v wet.
# eh
# ['eh']
# u
# ['eh', 'u']
# remember
# ['eh', 'u', 'remember']
# 2
# ['eh', 'u', 'remember', '2']
# spell
# ['eh', 'u', 'remember', '2', 'spell']
# yes
# ['eh', 'u', 'remember', '2', 'spell', 'yes']
# v
# ['eh', 'u', 'remember', '2', 'spell', 'yes', 'v']
# naughty
# ['eh', 'u', 'remember', '2', 'spell', 'yes', 'v', 'naughty']
# v
# ['eh', 'u', 'remember', '2', 'spell', 'yes', 'v', 'naughty', 'v']
# wet
# ['eh', 'u', 'remember', '2', 'spell', 'yes', 'v', 'naughty', 'v', 'wet']
# fine if thatåõs the way u feel. thatåõs the way its gota b
# fine
# ['fine']
# thatåõs
# ['fine', 'thatåõs']
# way
# ['fine', 'thatåõs', 'way']
# u
# ['fine', 'thatåõs', 'way', 'u']
# feel
# ['fine', 'thatåõs', 'way', 'u', 'feel']
# thatåõs
# ['fine', 'thatåõs', 'way', 'u', 'feel', 'thatåõs']
# way
# ['fine', 'thatåõs', 'way', 'u', 'feel', 'thatåõs', 'way']
# gota
# ['fine', 'thatåõs', 'way', 'u', 'feel', 'thatåõs', 'way', 'gota']
# b
# ['fine', 'thatåõs', 'way', 'u', 'feel', 'thatåõs', 'way', 'gota', 'b']
# england v macedonia - dont miss the goals/team news. txt ur national team to 87077 eg england to 87077 try:wales, scotland 4txt/ì¼1.20 poboxox36504w45wq 16+
# england
# ['england']
# v
# ['england', 'v']
# macedonia
# ['england', 'v', 'macedonia']
# nt
# ['england', 'v', 'macedonia', 'not']
# miss
# ['england', 'v', 'macedonia', 'not', 'miss']
# goals
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal']
# team
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team']
# news
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news']
# txt
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt']
# ur
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur']
# national
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national']
# team
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team']
# 87077
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077']
# eg
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg']
# england
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england']
# 87077
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077']
# try
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try']
# wales
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales']
# scotland
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland']
# 4txt
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland', '4txt']
# ì¼1.20
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland', '4txt', 'ì¼1.20']
# poboxox36504w45wq
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland', '4txt', 'ì¼1.20', 'poboxox36504w45wq']
# 16
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland', '4txt', 'ì¼1.20', 'poboxox36504w45wq', '16']
# +
# ['england', 'v', 'macedonia', 'not', 'miss', 'goal', 'team', 'news', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try', 'wales', 'scotland', '4txt', 'ì¼1.20', 'poboxox36504w45wq', '16', '+']
# is that seriously how you spell his name?
# seriously
# ['seriously']
# spell
# ['seriously', 'spell']
# i‰û÷m going to try for 2 months ha ha only joking
# i‰û÷m
# ['i‰û÷m']
# going
# ['i‰û÷m', 'go']
# try
# ['i‰û÷m', 'go', 'try']
# 2
# ['i‰û÷m', 'go', 'try', '2']
# months
# ['i‰û÷m', 'go', 'try', '2', 'month']
# ha
# ['i‰û÷m', 'go', 'try', '2', 'month', 'ha']
# ha
# ['i‰û÷m', 'go', 'try', '2', 'month', 'ha', 'ha']
# joking
# ['i‰û÷m', 'go', 'try', '2', 'month', 'ha', 'ha', 'joke']
# so ì_ pay first lar... then when is da stock comin...
# ì
# ['ì']
# pay
# ['ì', 'pay']
# lar
# ['ì', 'pay', 'lar']
# da
# ['ì', 'pay', 'lar', 'da']
# stock
# ['ì', 'pay', 'lar', 'da', 'stock']
# comin
# ['ì', 'pay', 'lar', 'da', 'stock', 'comin']
# aft i finish my lunch then i go str down lor. ard 3 smth lor. u finish ur lunch already?
# aft
# ['aft']
# finish
# ['aft', 'finish']
# lunch
# ['aft', 'finish', 'lunch']
# str
# ['aft', 'finish', 'lunch', 'str']
# lor
# ['aft', 'finish', 'lunch', 'str', 'lor']
# ard
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard']
# 3
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3']
# smth
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3', 'smth']
# lor
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3', 'smth', 'lor']
# u
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3', 'smth', 'lor', 'u']
# finish
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3', 'smth', 'lor', 'u', 'finish']
# ur
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3', 'smth', 'lor', 'u', 'finish', 'ur']
# lunch
# ['aft', 'finish', 'lunch', 'str', 'lor', 'ard', '3', 'smth', 'lor', 'u', 'finish', 'ur', 'lunch']
# ffffffffff. alright no way i can meet up with you sooner?
# ffffffffff
# ['ffffffffff']
# alright
# ['ffffffffff', 'alright']
# way
# ['ffffffffff', 'alright', 'way']
# meet
# ['ffffffffff', 'alright', 'way', 'meet']
# sooner
# ['ffffffffff', 'alright', 'way', 'meet', 'soon']
# just forced myself to eat a slice. i'm really not hungry tho. this sucks. mark is getting worried. he knows i'm sick when i turn down pizza. lol
# forced
# ['force']
# eat
# ['force', 'eat']
# slice
# ['force', 'eat', 'slice']
# hungry
# ['force', 'eat', 'slice', 'hungry']
# tho
# ['force', 'eat', 'slice', 'hungry', 'tho']
# sucks
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck']
# mark
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark']
# getting
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get']
# worried
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry']
# knows
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know']
# sick
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know', 'sick']
# turn
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know', 'sick', 'turn']
# pizza
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know', 'sick', 'turn', 'pizza']
# lol
# ['force', 'eat', 'slice', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know', 'sick', 'turn', 'pizza', 'lol']
# lol your always so convincing.
# lol
# ['lol']
# convincing
# ['lol', 'convincing']
# did you catch the bus ? are you frying an egg ? did you make a tea? are you eating your mom's left over dinner ? do you feel my love ?
# catch
# ['catch']
# bus
# ['catch', 'bus']
# frying
# ['catch', 'bus', 'fry']
# egg
# ['catch', 'bus', 'fry', 'egg']
# tea
# ['catch', 'bus', 'fry', 'egg', 'tea']
# eating
# ['catch', 'bus', 'fry', 'egg', 'tea', 'eat']
# mom
# ['catch', 'bus', 'fry', 'egg', 'tea', 'eat', 'mom']
# left
# ['catch', 'bus', 'fry', 'egg', 'tea', 'eat', 'mom', 'leave']
# dinner
# ['catch', 'bus', 'fry', 'egg', 'tea', 'eat', 'mom', 'leave', 'dinner']
# feel
# ['catch', 'bus', 'fry', 'egg', 'tea', 'eat', 'mom', 'leave', 'dinner', 'feel']
# love
# ['catch', 'bus', 'fry', 'egg', 'tea', 'eat', 'mom', 'leave', 'dinner', 'feel', 'love']
# i'm back &amp; we're packing the car now, i'll let you know if there's room
# amp
# ['amp']
# packing
# ['amp', 'pack']
# car
# ['amp', 'pack', 'car']
# let
# ['amp', 'pack', 'car', 'let']
# know
# ['amp', 'pack', 'car', 'let', 'know']
# room
# ['amp', 'pack', 'car', 'let', 'know', 'room']
# ahhh. work. i vaguely remember that! what does it feel like? lol
# ahhh
# ['ahhh']
# work
# ['ahhh', 'work']
# vaguely
# ['ahhh', 'work', 'vaguely']
# remember
# ['ahhh', 'work', 'vaguely', 'remember']
# feel
# ['ahhh', 'work', 'vaguely', 'remember', 'feel']
# like
# ['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like']
# lol
# ['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol']
# wait that's still not all that clear, were you not sure about me being sarcastic or that that's why x doesn't want to live with us
# wait
# ['wait']
# clear
# ['wait', 'clear']
# sure
# ['wait', 'clear', 'sure']
# sarcastic
# ['wait', 'clear', 'sure', 'sarcastic']
# x
# ['wait', 'clear', 'sure', 'sarcastic', 'x']
# want
# ['wait', 'clear', 'sure', 'sarcastic', 'x', 'want']
# live
# ['wait', 'clear', 'sure', 'sarcastic', 'x', 'want', 'live']
# yeah he got in at 2 and was v apologetic. n had fallen out and she was actin like spoilt child and he got caught up in that. till 2! but we won't go there! not doing too badly cheers. you?
# yeah
# ['yeah']
# got
# ['yeah', 'get']
# 2
# ['yeah', 'get', '2']
# v
# ['yeah', 'get', '2', 'v']
# apologetic
# ['yeah', 'get', '2', 'v', 'apologetic']
# n
# ['yeah', 'get', '2', 'v', 'apologetic', 'n']
# fallen
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall']
# actin
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin']
# like
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like']
# spoilt
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt']
# child
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child']
# got
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get']
# caught
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get', 'catch']
# till
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get', 'catch', 'till']
# 2
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get', 'catch', 'till', '2']
# wo
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get', 'catch', 'till', '2', 'will']
# badly
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get', 'catch', 'till', '2', 'will', 'badly']
# cheers
# ['yeah', 'get', '2', 'v', 'apologetic', 'n', 'fall', 'actin', 'like', 'spoilt', 'child', 'get', 'catch', 'till', '2', 'will', 'badly', 'cheer']
# k tell me anything about you.
# k
# ['k']
# tell
# ['k', 'tell']
# for fear of fainting with the of all that housework you just did? quick have a cuppa
# fear
# ['fear']
# fainting
# ['fear', 'faint']
# housework
# ['fear', 'faint', 'housework']
# quick
# ['fear', 'faint', 'housework', 'quick']
# cuppa
# ['fear', 'faint', 'housework', 'quick', 'cuppa']
# thanks for your subscription to ringtone uk your mobile will be charged å£5/month please confirm by replying yes or no. if you reply no you will not be charged
# thanks
# ['thank']
# subscription
# ['thank', 'subscription']
# ringtone
# ['thank', 'subscription', 'ringtone']
# uk
# ['thank', 'subscription', 'ringtone', 'uk']
# mobile
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile']
# charged
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge']
# å£5
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5']
# month
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5', 'month']
# confirm
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5', 'month', 'confirm']
# replying
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5', 'month', 'confirm', 'reply']
# yes
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5', 'month', 'confirm', 'reply', 'yes']
# reply
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5', 'month', 'confirm', 'reply', 'yes', 'reply']
# charged
# ['thank', 'subscription', 'ringtone', 'uk', 'mobile', 'charge', 'å£5', 'month', 'confirm', 'reply', 'yes', 'reply', 'charge']
# yup... ok i go home look at the timings then i msg ì_ again... xuhui going to learn on 2nd may too but her lesson is at 8am
# yup
# ['yup']
# ok
# ['yup', 'ok']
# home
# ['yup', 'ok', 'home']
# look
# ['yup', 'ok', 'home', 'look']
# timings
# ['yup', 'ok', 'home', 'look', 'timing']
# msg
# ['yup', 'ok', 'home', 'look', 'timing', 'msg']
# ì
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì']
# xuhui
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì', 'xuhui']
# going
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì', 'xuhui', 'go']
# learn
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì', 'xuhui', 'go', 'learn']
# 2nd
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì', 'xuhui', 'go', 'learn', '2nd']
# lesson
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì', 'xuhui', 'go', 'learn', '2nd', 'lesson']
# 8
# ['yup', 'ok', 'home', 'look', 'timing', 'msg', 'ì', 'xuhui', 'go', 'learn', '2nd', 'lesson', '8']
# oops, i'll let you know when my roommate's done
# oops
# ['oops']
# let
# ['oops', 'let']
# know
# ['oops', 'let', 'know']
# roommate
# ['oops', 'let', 'know', 'roommate']
# i see the letter b on my car
# letter
# ['letter']
# b
# ['letter', 'b']
# car
# ['letter', 'b', 'car']
# anything lor... u decide...
# lor
# ['lor']
# u
# ['lor', 'u']
# decide
# ['lor', 'u', 'decide']
# hello! how's you and how did saturday go? i was just texting to see if you'd decided to do anything tomo. not that i'm trying to invite myself or anything!
# hello
# ['hello']
# saturday
# ['hello', 'saturday']
# texting
# ['hello', 'saturday', 'texte']
# decided
# ['hello', 'saturday', 'texte', 'decide']
# tomo
# ['hello', 'saturday', 'texte', 'decide', 'tomo']
# trying
# ['hello', 'saturday', 'texte', 'decide', 'tomo', 'try']
# invite
# ['hello', 'saturday', 'texte', 'decide', 'tomo', 'try', 'invite']
# pls go ahead with watts. i just wanted to be sure. do have a great weekend. abiola
# pls
# ['pls']
# ahead
# ['pls', 'ahead']
# watts
# ['pls', 'ahead', 'watts']
# wanted
# ['pls', 'ahead', 'watts', 'want']
# sure
# ['pls', 'ahead', 'watts', 'want', 'sure']
# great
# ['pls', 'ahead', 'watts', 'want', 'sure', 'great']
# weekend
# ['pls', 'ahead', 'watts', 'want', 'sure', 'great', 'weekend']
# abiola
# ['pls', 'ahead', 'watts', 'want', 'sure', 'great', 'weekend', 'abiola']
# did i forget to tell you ? i want you , i need you, i crave you ... but most of all ... i love you my sweet arabian steed ... mmmmmm ... yummy
# forget
# ['forget']
# tell
# ['forget', 'tell']
# want
# ['forget', 'tell', 'want']
# need
# ['forget', 'tell', 'want', 'need']
# crave
# ['forget', 'tell', 'want', 'need', 'crave']
# love
# ['forget', 'tell', 'want', 'need', 'crave', 'love']
# sweet
# ['forget', 'tell', 'want', 'need', 'crave', 'love', 'sweet']
# arabian
# ['forget', 'tell', 'want', 'need', 'crave', 'love', 'sweet', 'arabian']
# steed
# ['forget', 'tell', 'want', 'need', 'crave', 'love', 'sweet', 'arabian', 'steed']
# mmmmmm
# ['forget', 'tell', 'want', 'need', 'crave', 'love', 'sweet', 'arabian', 'steed', 'mmmmmm']
# yummy
# ['forget', 'tell', 'want', 'need', 'crave', 'love', 'sweet', 'arabian', 'steed', 'mmmmmm', 'yummy']
# 07732584351 - rodger burns - msg = we tried to call you re your reply to our sms for a free nokia mobile + free camcorder. please call now 08000930705 for delivery tomorrow
# 07732584351
# ['07732584351']
# rodger
# ['07732584351', 'rodger']
# burns
# ['07732584351', 'rodger', 'burn']
# msg
# ['07732584351', 'rodger', 'burn', 'msg']
# =
# ['07732584351', 'rodger', 'burn', 'msg', '=']
# tried
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try']
# reply
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply']
# sms
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms']
# free
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free']
# nokia
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia']
# mobile
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile']
# +
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile', '+']
# free
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile', '+', 'free']
# camcorder
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile', '+', 'free', 'camcorder']
# 08000930705
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile', '+', 'free', 'camcorder', '08000930705']
# delivery
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile', '+', 'free', 'camcorder', '08000930705', 'delivery']
# tomorrow
# ['07732584351', 'rodger', 'burn', 'msg', '=', 'try', 'reply', 'sms', 'free', 'nokia', 'mobile', '+', 'free', 'camcorder', '08000930705', 'delivery', 'tomorrow']
# who are you seeing?
# seeing
# ['see']
# great! i hope you like your man well endowed. i am  &lt;#&gt;  inches...
# great
# ['great']
# hope
# ['great', 'hope']
# like
# ['great', 'hope', 'like']
# man
# ['great', 'hope', 'like', 'man']
# endowed
# ['great', 'hope', 'like', 'man', 'endowed']
#
# ['great', 'hope', 'like', 'man', 'endowed', ' ']
# lt;#&gt
# ['great', 'hope', 'like', 'man', 'endowed', ' ', 'lt;#&gt']
#
# ['great', 'hope', 'like', 'man', 'endowed', ' ', 'lt;#&gt', ' ']
# inches
# ['great', 'hope', 'like', 'man', 'endowed', ' ', 'lt;#&gt', ' ', 'inch']
# no calls..messages..missed calls
# calls
# ['call']
# messages
# ['call', 'message']
# missed
# ['call', 'message', 'missed']
# calls
# ['call', 'message', 'missed', 'call']
# didn't you get hep b immunisation in nigeria.
# hep
# ['hep']
# b
# ['hep', 'b']
# immunisation
# ['hep', 'b', 'immunisation']
# nigeria
# ['hep', 'b', 'immunisation', 'nigeria']
# fair enough, anything going on?
# fair
# ['fair']
# going
# ['fair', 'go']
# yeah hopefully, if tyler can't do it i could maybe ask around a bit
# yeah
# ['yeah']
# hopefully
# ['yeah', 'hopefully']
# tyler
# ['yeah', 'hopefully', 'tyler']
# maybe
# ['yeah', 'hopefully', 'tyler', 'maybe']
# ask
# ['yeah', 'hopefully', 'tyler', 'maybe', 'ask']
# bit
# ['yeah', 'hopefully', 'tyler', 'maybe', 'ask', 'bit']
# u don't know how stubborn i am. i didn't even want to go to the hospital. i kept telling mark i'm not a weak sucker. hospitals are for weak suckers.
# u
# ['u']
# know
# ['u', 'know']
# stubborn
# ['u', 'know', 'stubborn']
# want
# ['u', 'know', 'stubborn', 'want']
# hospital
# ['u', 'know', 'stubborn', 'want', 'hospital']
# kept
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep']
# telling
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell']
# mark
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell', 'mark']
# weak
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell', 'mark', 'weak']
# sucker
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell', 'mark', 'weak', 'sucker']
# hospitals
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell', 'mark', 'weak', 'sucker', 'hospital']
# weak
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell', 'mark', 'weak', 'sucker', 'hospital', 'weak']
# suckers
# ['u', 'know', 'stubborn', 'want', 'hospital', 'keep', 'tell', 'mark', 'weak', 'sucker', 'hospital', 'weak', 'sucker']
# what you thinked about me. first time you saw me in class.
# thinked
# ['think']
# time
# ['think', 'time']
# saw
# ['think', 'time', 'see']
# class
# ['think', 'time', 'see', 'class']
# a gram usually runs like  &lt;#&gt; , a half eighth is smarter though and gets you almost a whole second gram for  &lt;#&gt;
# gram
# ['gram']
# usually
# ['gram', 'usually']
# runs
# ['gram', 'usually', 'run']
# like
# ['gram', 'usually', 'run', 'like']
#
# ['gram', 'usually', 'run', 'like', ' ']
# lt;#&gt
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt']
# half
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half']
# eighth
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth']
# smarter
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth', 'smart']
# gets
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth', 'smart', 'get']
# second
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth', 'smart', 'get', 'second']
# gram
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth', 'smart', 'get', 'second', 'gram']
#
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth', 'smart', 'get', 'second', 'gram', ' ']
# lt;#&gt
# ['gram', 'usually', 'run', 'like', ' ', 'lt;#&gt', 'half', 'eighth', 'smart', 'get', 'second', 'gram', ' ', 'lt;#&gt']
# k fyi x has a ride early tomorrow morning but he's crashing at our place tonight
# k
# ['k']
# fyi
# ['k', 'fyi']
# x
# ['k', 'fyi', 'x']
# ride
# ['k', 'fyi', 'x', 'ride']
# early
# ['k', 'fyi', 'x', 'ride', 'early']
# tomorrow
# ['k', 'fyi', 'x', 'ride', 'early', 'tomorrow']
# morning
# ['k', 'fyi', 'x', 'ride', 'early', 'tomorrow', 'morning']
# crashing
# ['k', 'fyi', 'x', 'ride', 'early', 'tomorrow', 'morning', 'crash']
# place
# ['k', 'fyi', 'x', 'ride', 'early', 'tomorrow', 'morning', 'crash', 'place']
# tonight
# ['k', 'fyi', 'x', 'ride', 'early', 'tomorrow', 'morning', 'crash', 'place', 'tonight']
# wow. i never realized that you were so embarassed by your accomodations. i thought you liked it, since i was doing the best i could and you always seemed so happy about \the cave\". i'm sorry i didn't and don't have more to give. i'm sorry i offered. i'm sorry your room was so embarassing."
# wow
# ['wow']
# realized
# ['wow', 'realize']
# embarassed
# ['wow', 'realize', 'embarasse']
# accomodations
# ['wow', 'realize', 'embarasse', 'accomodation']
# thought
# ['wow', 'realize', 'embarasse', 'accomodation', 'think']
# liked
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like']
# best
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good']
# happy
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy']
# \the
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the']
# cave\
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\']
# sorry
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\', 'sorry']
# sorry
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\', 'sorry', 'sorry']
# offered
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\', 'sorry', 'sorry', 'offer']
# sorry
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\', 'sorry', 'sorry', 'offer', 'sorry']
# room
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\', 'sorry', 'sorry', 'offer', 'sorry', 'room']
# embarassing
# ['wow', 'realize', 'embarasse', 'accomodation', 'think', 'like', 'good', 'happy', '\\the', 'cave\\', 'sorry', 'sorry', 'offer', 'sorry', 'room', 'embarassing']
# sms. ac sptv: the new jersey devils and the detroit red wings play ice hockey. correct or incorrect? end? reply end sptv
# sms
# ['sms']
# ac
# ['sms', 'ac']
# sptv
# ['sms', 'ac', 'sptv']
# new
# ['sms', 'ac', 'sptv', 'new']
# jersey
# ['sms', 'ac', 'sptv', 'new', 'jersey']
# devils
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils']
# detroit
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit']
# red
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red']
# wings
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing']
# play
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play']
# ice
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice']
# hockey
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey']
# correct
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct']
# incorrect
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect']
# end
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end']
# reply
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'reply']
# end
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'reply', 'end']
# sptv
# ['sms', 'ac', 'sptv', 'new', 'jersey', 'devils', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'reply', 'end', 'sptv']
# do you know what mallika sherawat did yesterday? find out now @  &lt;url&gt;
# know
# ['know']
# mallika
# ['know', 'mallika']
# sherawat
# ['know', 'mallika', 'sherawat']
# yesterday
# ['know', 'mallika', 'sherawat', 'yesterday']
# find
# ['know', 'mallika', 'sherawat', 'yesterday', 'find']
#
# ['know', 'mallika', 'sherawat', 'yesterday', 'find', ' ']
# lt;url&gt
# ['know', 'mallika', 'sherawat', 'yesterday', 'find', ' ', 'lt;url&gt']
# congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc all 4 free! bx420-ip4-5we. 150pm. dont miss out!
# congrats
# ['congrat']
# 1
# ['congrat', '1']
# year
# ['congrat', '1', 'year']
# special
# ['congrat', '1', 'year', 'special']
# cinema
# ['congrat', '1', 'year', 'special', 'cinema']
# pass
# ['congrat', '1', 'year', 'special', 'cinema', 'pass']
# 2
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2']
# 09061209465
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465']
# c
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c']
# suprman
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman']
# v
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v']
# matrix3
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3']
# starwars3
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3']
# etc
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc']
# 4
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4']
# free
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free']
# bx420-ip4
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', 'bx420-ip4']
# 5we
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', 'bx420-ip4', '5we']
# 150pm
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', 'bx420-ip4', '5we', '150pm']
# nt
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', 'bx420-ip4', '5we', '150pm', 'not']
# miss
# ['congrat', '1', 'year', 'special', 'cinema', 'pass', '2', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', 'bx420-ip4', '5we', '150pm', 'not', 'miss']
# sorry, i'll call later in meeting.
# sorry
# ['sorry']
# later
# ['sorry', 'later']
# meeting
# ['sorry', 'later', 'meeting']
# tell where you reached
# tell
# ['tell']
# reached
# ['tell', 'reach']
# yes..gauti and sehwag out of odi series.
# yes
# ['yes']
# gauti
# ['yes', 'gauti']
# sehwag
# ['yes', 'gauti', 'sehwag']
# odi
# ['yes', 'gauti', 'sehwag', 'odi']
# series
# ['yes', 'gauti', 'sehwag', 'odi', 'series']
# your gonna have to pick up a $1 burger for yourself on your way home. i can't even move. pain is killing me.
# gon
# ['go']
# na
# ['go', 'to']
# pick
# ['go', 'to', 'pick']
# $
# ['go', 'to', 'pick', '$']
# 1
# ['go', 'to', 'pick', '$', '1']
# burger
# ['go', 'to', 'pick', '$', '1', 'burger']
# way
# ['go', 'to', 'pick', '$', '1', 'burger', 'way']
# home
# ['go', 'to', 'pick', '$', '1', 'burger', 'way', 'home']
# pain
# ['go', 'to', 'pick', '$', '1', 'burger', 'way', 'home', 'pain']
# killing
# ['go', 'to', 'pick', '$', '1', 'burger', 'way', 'home', 'pain', 'kill']
# ha ha ha good joke. girls are situation seekers.
# ha
# ['ha']
# ha
# ['ha', 'ha']
# ha
# ['ha', 'ha', 'ha']
# good
# ['ha', 'ha', 'ha', 'good']
# joke
# ['ha', 'ha', 'ha', 'good', 'joke']
# girls
# ['ha', 'ha', 'ha', 'good', 'joke', 'girl']
# situation
# ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situation']
# seekers
# ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situation', 'seeker']
# its a part of checking iq
# checking
# ['check']
# iq
# ['check', 'iq']
# sorry my roommates took forever, it ok if i come by now?
# sorry
# ['sorry']
# roommates
# ['sorry', 'roommate']
# took
# ['sorry', 'roommate', 'take']
# forever
# ['sorry', 'roommate', 'take', 'forever']
# ok
# ['sorry', 'roommate', 'take', 'forever', 'ok']
# come
# ['sorry', 'roommate', 'take', 'forever', 'ok', 'come']
# ok lar i double check wif da hair dresser already he said wun cut v short. he said will cut until i look nice.
# ok
# ['ok']
# lar
# ['ok', 'lar']
# double
# ['ok', 'lar', 'double']
# check
# ['ok', 'lar', 'double', 'check']
# wif
# ['ok', 'lar', 'double', 'check', 'wif']
# da
# ['ok', 'lar', 'double', 'check', 'wif', 'da']
# hair
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair']
# dresser
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair', 'dresser']
# said
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'say']
# wun
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'say', 'wun']
# cut
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'say', 'wun', 'cut']
# v
# ['ok', 'lar', 'double', 'check', 'wif', 'da', 'hair', 'dresser', 'say', 'wun', 'cut', 'v']
# short
# ...
#
# [' ']
#
# [' ', ' ']
# picking
# [' ', ' ', 'pick']
# points
# [' ', ' ', 'pick', 'point']
# |
# [' ', ' ', 'pick', 'point', '|']
# going
# [' ', ' ', 'pick', 'point', '|', 'go']
# 2
# [' ', ' ', 'pick', 'point', '|', 'go', '2']
# yeovil
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil']
# |
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|']
# motor
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor']
# project
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project']
# 4
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4']
# 3
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3']
# hours
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour']
# |
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|']
# u
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u']
# home
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home']
# ||
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||']
# 12
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||', '12']
# 2
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||', '12', '2']
# 5.30
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||', '12', '2', '5.30']
# max
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||', '12', '2', '5.30', 'max']
# ||
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||', '12', '2', '5.30', 'max', '||']
# easy
# [' ', ' ', 'pick', 'point', '|', 'go', '2', 'yeovil', '|', 'motor', 'project', '4', '3', 'hour', '|', 'u', 'home', '||', '12', '2', '5.30', 'max', '||', 'easy']
# also fuck you and your family for going to rhode island or wherever the fuck and leaving me all alone the week i have a new bong &gt;:(
# fuck
# ['fuck']
# family
# ['fuck', 'family']
# going
# ['fuck', 'family', 'go']
# rhode
# ['fuck', 'family', 'go', 'rhode']
# island
# ['fuck', 'family', 'go', 'rhode', 'island']
# fuck
# ['fuck', 'family', 'go', 'rhode', 'island', 'fuck']
# leaving
# ['fuck', 'family', 'go', 'rhode', 'island', 'fuck', 'leave']
# week
# ['fuck', 'family', 'go', 'rhode', 'island', 'fuck', 'leave', 'week']
# new
# ['fuck', 'family', 'go', 'rhode', 'island', 'fuck', 'leave', 'week', 'new']
# bong
# ['fuck', 'family', 'go', 'rhode', 'island', 'fuck', 'leave', 'week', 'new', 'bong']
# gt
# ['fuck', 'family', 'go', 'rhode', 'island', 'fuck', 'leave', 'week', 'new', 'bong', 'gt']
# ofcourse i also upload some songs
# ofcourse
# ['ofcourse']
# upload
# ['ofcourse', 'upload']
# songs
# ['ofcourse', 'upload', 'song']
# 2p per min to call germany 08448350055 from your bt line. just 2p per min. check planettalkinstant.com for info & t's & c's. text stop to opt out
# 2p
# ['2p']
# min
# ['2p', 'min']
# germany
# ['2p', 'min', 'germany']
# 08448350055
# ['2p', 'min', 'germany', '08448350055']
# bt
# ['2p', 'min', 'germany', '08448350055', 'bt']
# line
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line']
# 2p
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p']
# min
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min']
# check
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check']
# planettalkinstant.com
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com']
# info
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com', 'info']
# t
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com', 'info', 't']
# c
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com', 'info', 't', 'c']
# text
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com', 'info', 't', 'c', 'text']
# stop
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com', 'info', 't', 'c', 'text', 'stop']
# opt
# ['2p', 'min', 'germany', '08448350055', 'bt', 'line', '2p', 'min', 'check', 'planettalkinstant.com', 'info', 't', 'c', 'text', 'stop', 'opt']
# k. i will sent it again
# k.
# ['k.']
# sent
# ['k.', 'send']
# oh thanks a lot..i already bought 2 eggs ..
# oh
# ['oh']
# thanks
# ['oh', 'thanks']
# lot
# ['oh', 'thanks', 'lot']
# bought
# ['oh', 'thanks', 'lot', 'buy']
# 2
# ['oh', 'thanks', 'lot', 'buy', '2']
# eggs
# ['oh', 'thanks', 'lot', 'buy', '2', 'egg']
# k. i will sent it again
# k.
# ['k.']
# sent
# ['k.', 'send']
# u studying in sch or going home? anyway i'll b going 2 sch later.
# u
# ['u']
# studying
# ['u', 'study']
# sch
# ['u', 'study', 'sch']
# going
# ['u', 'study', 'sch', 'go']
# home
# ['u', 'study', 'sch', 'go', 'home']
# b
# ['u', 'study', 'sch', 'go', 'home', 'b']
# going
# ['u', 'study', 'sch', 'go', 'home', 'b', 'go']
# 2
# ['u', 'study', 'sch', 'go', 'home', 'b', 'go', '2']
# sch
# ['u', 'study', 'sch', 'go', 'home', 'b', 'go', '2', 'sch']
# later
# ['u', 'study', 'sch', 'go', 'home', 'b', 'go', '2', 'sch', 'later']
# marvel mobile play the official ultimate spider-man game (å£4.50) on ur mobile right now. text spider to 83338 for the game & we ll send u a free 8ball wallpaper
# marvel
# ['marvel']
# mobile
# ['marvel', 'mobile']
# play
# ['marvel', 'mobile', 'play']
# official
# ['marvel', 'mobile', 'play', 'official']
# ultimate
# ['marvel', 'mobile', 'play', 'official', 'ultimate']
# spider
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider']
# man
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man']
# game
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game']
# å£4.50
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50']
# ur
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur']
# mobile
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile']
# right
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right']
# text
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text']
# spider
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider']
# 83338
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338']
# game
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game']
# ll
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game', 'will']
# send
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game', 'will', 'send']
# u
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game', 'will', 'send', 'u']
# free
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game', 'will', 'send', 'u', 'free']
# 8ball
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game', 'will', 'send', 'u', 'free', '8ball']
# wallpaper
# ['marvel', 'mobile', 'play', 'official', 'ultimate', 'spider', 'man', 'game', 'å£4.50', 'ur', 'mobile', 'right', 'text', 'spider', '83338', 'game', 'will', 'send', 'u', 'free', '8ball', 'wallpaper']
# i think if he rule tamilnadu..then its very tough for our people.
# think
# ['think']
# rule
# ['think', 'rule']
# tamilnadu
# ['think', 'rule', 'tamilnadu']
# tough
# ['think', 'rule', 'tamilnadu', 'tough']
# people
# ['think', 'rule', 'tamilnadu', 'tough', 'people']
# cool, we shall go and see, have to go to tip anyway. are you at home, got something to drop in later? so lets go to town tonight! maybe mum can take us in.
# cool
# ['cool']
# shall
# ['cool', 'shall']
# tip
# ['cool', 'shall', 'tip']
# home
# ['cool', 'shall', 'tip', 'home']
# got
# ['cool', 'shall', 'tip', 'home', 'get']
# drop
# ['cool', 'shall', 'tip', 'home', 'get', 'drop']
# later
# ['cool', 'shall', 'tip', 'home', 'get', 'drop', 'later']
# lets
# ['cool', 'shall', 'tip', 'home', 'get', 'drop', 'later', 'let']
# town
# ['cool', 'shall', 'tip', 'home', 'get', 'drop', 'later', 'let', 'town']
# tonight
# ['cool', 'shall', 'tip', 'home', 'get', 'drop', 'later', 'let', 'town', 'tonight']
# maybe
# ['cool', 'shall', 'tip', 'home', 'get', 'drop', 'later', 'let', 'town', 'tonight', 'maybe']
# mum
# ['cool', 'shall', 'tip', 'home', 'get', 'drop', 'later', 'let', 'town', 'tonight', 'maybe', 'mum']
# good afternoon, my love ... how goes your day ? how did you sleep ? i hope your well, my boytoy ... i think of you ...
# good
# ['good']
# afternoon
# ['good', 'afternoon']
# love
# ['good', 'afternoon', 'love']
# goes
# ['good', 'afternoon', 'love', 'go']
# day
# ['good', 'afternoon', 'love', 'go', 'day']
# sleep
# ['good', 'afternoon', 'love', 'go', 'day', 'sleep']
# hope
# ['good', 'afternoon', 'love', 'go', 'day', 'sleep', 'hope']
# boytoy
# ['good', 'afternoon', 'love', 'go', 'day', 'sleep', 'hope', 'boytoy']
# think
# ['good', 'afternoon', 'love', 'go', 'day', 'sleep', 'hope', 'boytoy', 'think']
# yes... i trust u to buy new stuff asap so i can try it out
# yes
# ['yes']
# trust
# ['yes', 'trust']
# u
# ['yes', 'trust', 'u']
# buy
# ['yes', 'trust', 'u', 'buy']
# new
# ['yes', 'trust', 'u', 'buy', 'new']
# stuff
# ['yes', 'trust', 'u', 'buy', 'new', 'stuff']
# asap
# ['yes', 'trust', 'u', 'buy', 'new', 'stuff', 'asap']
# try
# ['yes', 'trust', 'u', 'buy', 'new', 'stuff', 'asap', 'try']
# sms services. for your inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with stop, no extra charge. help 08702840625.comuk. 220-cm2 9ae
# sms
# ['sms']
# services
# ['sms', 'services']
# inclusive
# ['sms', 'services', 'inclusive']
# text
# ['sms', 'services', 'inclusive', 'text']
# credits
# ['sms', 'services', 'inclusive', 'text', 'credit']
# pls
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls']
# goto
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto']
# www.comuk.net
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net']
# login=
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=']
# 3qxj9
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9']
# unsubscribe
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe']
# stop
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop']
# extra
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop', 'extra']
# charge
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop', 'extra', 'charge']
# help
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop', 'extra', 'charge', 'help']
# 08702840625.comuk
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop', 'extra', 'charge', 'help', '08702840625.comuk']
# 220-cm2
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop', 'extra', 'charge', 'help', '08702840625.comuk', '220-cm2']
# 9ae
# ['sms', 'services', 'inclusive', 'text', 'credit', 'pls', 'goto', 'www.comuk.net', 'login=', '3qxj9', 'unsubscribe', 'stop', 'extra', 'charge', 'help', '08702840625.comuk', '220-cm2', '9ae']
# why did i wake up on my own &gt;:(
# wake
# ['wake']
# gt
# ['wake', 'gt']
# now get step 2 outta the way. congrats again.
# step
# ['step']
# 2
# ['step', '2']
# outta
# ['step', '2', 'outta']
# way
# ['step', '2', 'outta', 'way']
# congrats
# ['step', '2', 'outta', 'way', 'congrat']
# love has one law; make happy the person you love. in the same way friendship has one law; never make ur friend feel alone until you are alive.... gud night
# love
# ['love']
# law
# ['love', 'law']
# happy
# ['love', 'law', 'happy']
# person
# ['love', 'law', 'happy', 'person']
# love
# ['love', 'law', 'happy', 'person', 'love']
# way
# ['love', 'law', 'happy', 'person', 'love', 'way']
# friendship
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship']
# law
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law']
# ur
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law', 'ur']
# friend
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law', 'ur', 'friend']
# feel
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law', 'ur', 'friend', 'feel']
# alive
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law', 'ur', 'friend', 'feel', 'alive']
# gud
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law', 'ur', 'friend', 'feel', 'alive', 'gud']
# night
# ['love', 'law', 'happy', 'person', 'love', 'way', 'friendship', 'law', 'ur', 'friend', 'feel', 'alive', 'gud', 'night']
# private! your 2003 account statement for 07808247860 shows 800 un-redeemed s. i. m. points. call 08719899229 identifier code: 40411 expires 06/11/04
# private
# ['private']
# 2003
# ['private', '2003']
# account
# ['private', '2003', 'account']
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim']
# easy
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy']
# 087187272008
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008']
# now1
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1']
# 10p
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p']
# minute
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute']
# bt
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute', 'bt']
# national
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute', 'bt', 'national']
# rate
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute', 'bt', 'national', 'rate']
# will ì_ b going to esplanade fr home?
# ì
# ['ì']
# b
# ['ì', 'b']
# going
# ['ì', 'b', 'go']
# esplanade
# ['ì', 'b', 'go', 'esplanade']
# fr
# ['ì', 'b', 'go', 'esplanade', 'fr']
# home
# ['ì', 'b', 'go', 'esplanade', 'fr', 'home']
# pity, * was in mood for that. so...any other suggestions?
# pity
# ['pity']
# mood
# ['pity', 'mood']
# suggestions
# ['pity', 'mood', 'suggestion']
# the guy did some bitching but i acted like i'd be interested in buying something else next week and he gave it to us for free
# guy
# ['guy']
# bitching
# ['guy', 'bitching']
# acted
# ['guy', 'bitching', 'act']
# like
# ['guy', 'bitching', 'act', 'like']
# interested
# ['guy', 'bitching', 'act', 'like', 'interested']
# buying
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy']
# week
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy', 'week']
# gave
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy', 'week', 'give']
# free
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy', 'week', 'give', 'free']
# rofl. its true to its name
# rofl
# ['rofl']
# true
# ['rofl', 'true']

# %%
data.head()
# Out:
#    v1                                                 v2
# 0   0  jurong point crazy available bugis n great wor...
# 1   0                            ok lar joking wif u oni
# 2   1  free entry 2 wkly comp win fa cup final tkts 2...
# 3   0                                u dun early hor u c
# 4   0                              nah think go usf live

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(analyzer='word',stop_words='english')

# %%
text_vector = vectorizer.fit_transform(data['v2'].values.tolist())

# %%
print(text_vector)
# Out:
#   (0, 7078)	0.19811280790775795
#   (0, 1019)	0.3572987963059997
#   (0, 1844)	0.3018474669592391
#   (0, 1594)	0.34108032216450296
#   (0, 3895)	0.3018474669592391
#   (0, 7251)	0.2395221825114365
#   (0, 3173)	0.19664476501746203
#   (0, 1597)	0.3133546574911226
#   (0, 1214)	0.26724784718481687
#   (0, 2075)	0.2716968368779707
#   (0, 5127)	0.25960569905648284
#   (0, 3787)	0.3572987963059997
#   (1, 4794)	0.5219215829817558
#   (1, 7171)	0.4121236206804225
#   (1, 3754)	0.581579385201324
#   (1, 3928)	0.3898730280853774
#   (1, 4770)	0.2598392256289764
#   (2, 77)	0.23950835337117854
#   (2, 1093)	0.17131780969931007
#   (2, 5411)	0.16472163998363368
#   (2, 6790)	0.12644435596103756
#   (2, 6208)	0.20057014521011052
#   (2, 5365)	0.16819370629513097
#   (2, 5453)	0.16472163998363368
#   (2, 778)	0.22516029351458408
#   :	:
#   (5567, 461)	0.24329988909140762
#   (5567, 6759)	0.19247634377521441
#   (5567, 4558)	0.2550290252643528
#   (5567, 6615)	0.16437959346516154
#   (5567, 5182)	0.24592049407392322
#   (5567, 1851)	0.19353365899354386
#   (5567, 5265)	0.20275106085743133
#   (5567, 5411)	0.2304422175873772
#   (5567, 7182)	0.1840573137774077
#   (5568, 2632)	0.6964402301279243
#   (5568, 2918)	0.6009943905379231
#   (5568, 3386)	0.39214378536617706
#   (5569, 5066)	0.6198322100581006
#   (5569, 6320)	0.5916968433151221
#   (5569, 4442)	0.5154637494387073
#   (5570, 1418)	0.5015083287926458
#   (5570, 887)	0.45006413140208523
#   (5570, 3615)	0.42367626275286013
#   (5570, 3219)	0.3087106615905987
#   (5570, 1623)	0.298023447978275
#   (5570, 4007)	0.23342576905295692
#   (5570, 7116)	0.269343670581178
#   (5570, 2929)	0.2351090119327462
#   (5571, 5617)	0.7930026248542038
#   (5571, 6751)	0.6092182178615007

# %%
######Splitting Data set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(text_vector.toarray(),data['v1'],test_size=0.2,random_state=20)

# %%
len(x_test)
# Out:
# 1115

# %%
####Model Building

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
modelB = BernoulliNB()
modelB.fit(x_train,y_train)
print(modelB.score(x_train,y_train))
# Out:
# 0.9845187345748261

# %%
y_predictedB = modelB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_predictedB))
# Out:
# 0.9829596412556054
